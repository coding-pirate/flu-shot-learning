# %%
import pandas as pd

# %%
from pathlib import Path
import numpy as np

# %%
# %matplotlib inline

# %%
data = pd.read_csv("/Users/kaushalshah/Desktop/Computer Science/DrivenData/training_set_features.csv")

# %%
data
# Out:
#        respondent_id  h1n1_concern  h1n1_knowledge  behavioral_antiviral_meds  \
# 0                  0           1.0             0.0                        0.0
# 1                  1           3.0             2.0                        0.0
# 2                  2           1.0             1.0                        0.0
# 3                  3           1.0             1.0                        0.0
# 4                  4           2.0             1.0                        0.0
# ...              ...           ...             ...                        ...
# 26702          26702           2.0             0.0                        0.0
# 26703          26703           1.0             2.0                        0.0
# 26704          26704           2.0             2.0                        0.0
# 26705          26705           1.0             1.0                        0.0
# 26706          26706           0.0             0.0                        0.0
#
# ...

# %%
data.shape
# Out:
# (26707, 36)

# %%
data.isnull().values.any()
# Out:
# True

# %%
labels_data = pd.read_csv("/Users/kaushalshah/Desktop/Computer Science/DrivenData/training_set_labels.csv")
labels_h1n1 = labels_data[['respondent_id','h1n1_vaccine']]
labels_seasonal = labels_data[['respondent_id','seasonal_vaccine']]

# %%
features_data = data

# %%
data_h1n1 = pd.merge(features_data, labels_h1n1)

# %%
data_seasonal = pd.merge(features_data, labels_seasonal)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
corrmat_h1n1 = data_h1n1.corr()
top_corr_features = corrmat_h1n1.index
plt.figure(figsize=(20,20))
g=sns.heatmap(data_h1n1[top_corr_features].corr(), annot=True, cmap = "RdYlGn")
